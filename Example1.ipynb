# %% [markdown]
# <a href="https://colab.research.google.com/github/hsabaghpour/Linear_Regression/blob/main/Example1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install statsmodels

# %%
import numpy as np
import statsmodels.api as sm

# Generate some sample data
np.random.seed(0)
X = np.random.rand(100, 1)  # Independent variable
y = 2 * X.squeeze() + np.random.normal(0, 0.1, 100)  # Dependent variable with some noise

# Add a constant to the independent variable for the intercept term
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the summary of the regression model
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.971
# Method:                 Least Squares   F-statistic:                     3262.
# Date:                Wed, 24 Apr 2024   Prob (F-statistic):           4.88e-77
# Time:                        04:10:19   Log-Likelihood:                 88.744
# No. Observations:                 100   AIC:                            -173.5
# Df Residuals:                      98   BIC:                            -168.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0222      0.019      1.149      0.253      -0.016       0.061
# ...

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Generate some sample data
np.random.seed(0)
X = np.random.rand(100, 1)  # Independent variable
y = 2 * X.squeeze() + np.random.normal(0, 0.1, 100)  # Dependent variable with some noise

# Add a constant to the independent variable for the intercept term
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Plot the data points
plt.scatter(X[:, 1], y, label='Data')

# Plot the regression line
plt.plot(X[:, 1], model.predict(), color='red', label='Regression Line')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()
